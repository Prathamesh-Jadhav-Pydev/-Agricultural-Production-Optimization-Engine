# %% [markdown]
# <a href="https://www.kaggle.com/code/prathameshjadhav2021/covid-19-data-visualization-with-map?scriptVersionId=91050278" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px
import folium 
from matplotlib import style
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/latest-covid19-cases-maharashtra-india/Maharashtra Latest Covid Cases.csv
# /kaggle/input/maharashtra-longiutde-and-latiude-dataset/Longitude and Latitude of Maharashtra.csv

# %%
dataframe = pd.read_csv("../input/latest-covid19-cases-maharashtra-india/Maharashtra Latest Covid Cases.csv")

# %% [markdown]
# **Read the dataset.**

# %%
# after impoering we read the database 
# shows by default first 5 rows of the dataset.
dataframe.head()
# Out:
#     Districts  Positive Cases  Active Cases  Recovered  Deceased  \
# 0  Ahmednagar          377366           162     369963      7230
# 1       Akola           66163             8      64686      1465
# 2    Amravati          105928             4     104300      1622
# 3  Aurangabad          176397            44     172069      4270
# 4        Beed          109104            15     106207      2875
#
#    Recovery Rate(%)  Fatality Rate(%)
# 0              98.0               1.9
# 1              97.8               2.2
# 2              98.5               1.5
# 3              97.5               2.4
# 4              97.3               2.6

# %%
dataframe.tail()
# Out:
#    Districts  Positive Cases  Active Cases  Recovered  Deceased  \
# 30   Solapur          227014            19     221119      5759
# 31     Thane          766512           168     754440     11869
# 32    Wardha           65663             1      64254      1237
# 33    Washim           45614             3      44970       638
# 34  Yavatmal           81978             0      80158      1816
#
#     Recovery Rate(%)  Fatality Rate(%)
# 30              97.4               2.5
# 31              98.4               1.5
# 32              97.9               1.9
# 33              98.6               1.4
# 34              97.8               2.2

# %% [markdown]
# Display list of columns present inside dataset

# %%
# display list of columns in the dataset
dataframe.columns
# Out:
# Index(['Districts', 'Positive Cases', 'Active Cases', 'Recovered', 'Deceased',
#        'Recovery Rate(%)', 'Fatality Rate(%)'],
#       dtype='object')

# %% [markdown]
# **Check null values or any missing data present inside the dataset.**

# %%
# then check null values in the dataset
dataframe.isnull().sum()
# Out:
# Districts           0
# Positive Cases      0
# Active Cases        0
# Recovered           0
# Deceased            0
# Recovery Rate(%)    0
# Fatality Rate(%)    0
# dtype: int64

# %% [markdown]
# **Check datatypes of each column in the dataset.**

# %%
dataframe.dtypes
# Out:
# Districts            object
# Positive Cases        int64
# Active Cases          int64
# Recovered             int64
# Deceased              int64
# Recovery Rate(%)    float64
# Fatality Rate(%)    float64
# dtype: object

# %% [markdown]
# **Check number of rows and columns present inside the dataset.**

# %%
col,row=dataframe.shape
print(f"Maharashtra Covid-19 dataset contain {col} columns and {row} rows.")
# Out:
# Maharashtra Covid-19 dataset contain 35 columns and 7 rows.

# %% [markdown]
# **Heat map of Covid 19 Cases in Maharashtra**

# %%
dataframe.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_f60fa_row0_col1, #T_f60fa_row0_col3 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_f60fa_row0_col2, #T_f60fa_row27_col4 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_f60fa_row0_col4 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_f60fa_row0_col5, #T_f60fa_row0_col6, #T_f60fa_row9_col5, #T_f60fa_row9_col6, #T_f60fa_row20_col6, #T_f60fa_row25_col5, #T_f60fa_row32_col6 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_f60fa_row1_col1, #T_f60fa_row1_col3, #T_f60fa_row13_col1, #T_f60fa_row13_col3, #T_f60fa_row30_col2, #T_f60fa_row32_col1, #T_f60fa_row32_col3 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_f60fa_row1_col2, #T_f60fa_row15_col2, #T_f60fa_row18_col2, #T_f60fa_row23_col2 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_f60fa_row1_col4, #T_f60fa_row6_col1, #T_f60fa_row6_col3, #T_f60fa_row21_col5, #T_f60fa_row28_col2 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_f60fa_row1_col5, #T_f60fa_row5_col6, #T_f60fa_row23_col5, #T_f60fa_row34_col5 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_f60fa_row1_col6, #T_f60fa_row5_col5, #T_f60fa_row34_col6 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_f60fa_row2_col1, #T_f60fa_row2_col4, #T_f60fa_row7_col4, #T_f60fa_row15_col1, #T_f60fa_row15_col3, #T_f60fa_row17_col2, #T_f60fa_row18_col1, #T_f60fa_row18_col3 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_f60fa_row2_col2, #T_f60fa_row7_col2, #T_f60fa_row8_col4, #T_f60fa_row12_col2, #T_f60fa_row19_col2, #T_f60fa_row33_col2, #T_f60fa_row33_col4 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_f60fa_row2_col3, #T_f60fa_row4_col1, #T_f60fa_row4_col3 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_f60fa_row2_col5, #T_f60fa_row3_col6, #T_f60fa_row15_col6, #T_f60fa_row24_col5, #T_f60fa_row28_col6 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_f60fa_row2_col6, #T_f60fa_row15_col5, #T_f60fa_row28_col5, #T_f60fa_row31_col6 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_f60fa_row3_col1, #T_f60fa_row3_col3 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_f60fa_row3_col2 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_f60fa_row3_col4, #T_f60fa_row8_col6, #T_f60fa_row10_col6, #T_f60fa_row18_col5, #T_f60fa_row30_col5 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_f60fa_row3_col5, #T_f60fa_row24_col6, #T_f60fa_row27_col5, #T_f60fa_row33_col6 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_f60fa_row4_col2, #T_f60fa_row10_col2, #T_f60fa_row23_col1, #T_f60fa_row23_col3, #T_f60fa_row29_col1, #T_f60fa_row29_col3 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_f60fa_row4_col4, #T_f60fa_row20_col2 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_f60fa_row4_col5, #T_f60fa_row14_col5, #T_f60fa_row27_col1, #T_f60fa_row27_col3, #T_f60fa_row29_col5, #T_f60fa_row30_col1, #T_f60fa_row30_col3 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_f60fa_row4_col6, #T_f60fa_row8_col5, #T_f60fa_row10_col5, #T_f60fa_row18_col6, #T_f60fa_row29_col6 {
#   background-color: #b81419;
#   color: #f1f1f1;
# }
# #T_f60fa_row5_col1, #T_f60fa_row5_col3, #T_f60fa_row5_col4, #T_f60fa_row6_col2 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_f60fa_row5_col2, #T_f60fa_row6_col6, #T_f60fa_row8_col2, #T_f60fa_row10_col4, #T_f60fa_row11_col1, #T_f60fa_row11_col2, #T_f60fa_row11_col3, #T_f60fa_row11_col4, #T_f60fa_row13_col2, #T_f60fa_row26_col5, #T_f60fa_row32_col2, #T_f60fa_row34_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_f60fa_row6_col4, #T_f60fa_row10_col1, #T_f60fa_row10_col3, #T_f60fa_row19_col1, #T_f60fa_row19_col3, #T_f60fa_row22_col2, #T_f60fa_row33_col1, #T_f60fa_row33_col3 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_f60fa_row6_col5, #T_f60fa_row24_col1, #T_f60fa_row24_col2, #T_f60fa_row24_col3, #T_f60fa_row24_col4, #T_f60fa_row26_col6 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f60fa_row7_col1, #T_f60fa_row7_col3, #T_f60fa_row25_col2, #T_f60fa_row29_col4 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_f60fa_row7_col5, #T_f60fa_row11_col6, #T_f60fa_row17_col5, #T_f60fa_row31_col5 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_f60fa_row7_col6, #T_f60fa_row11_col5, #T_f60fa_row16_col6, #T_f60fa_row17_col6 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_f60fa_row8_col1, #T_f60fa_row8_col3, #T_f60fa_row19_col4, #T_f60fa_row29_col2 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_f60fa_row9_col1, #T_f60fa_row9_col2, #T_f60fa_row9_col3, #T_f60fa_row9_col4, #T_f60fa_row21_col2, #T_f60fa_row26_col2, #T_f60fa_row27_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_f60fa_row12_col1, #T_f60fa_row12_col3 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_f60fa_row12_col4, #T_f60fa_row18_col4 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_f60fa_row12_col5, #T_f60fa_row13_col5, #T_f60fa_row19_col6, #T_f60fa_row22_col6, #T_f60fa_row23_col6 {
#   background-color: #f44f39;
#   color: #f1f1f1;
# }
# #T_f60fa_row12_col6, #T_f60fa_row13_col6, #T_f60fa_row19_col5, #T_f60fa_row20_col4, #T_f60fa_row22_col5, #T_f60fa_row32_col5 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_f60fa_row13_col4, #T_f60fa_row14_col2, #T_f60fa_row21_col1, #T_f60fa_row21_col3, #T_f60fa_row23_col4, #T_f60fa_row32_col4 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_f60fa_row14_col1, #T_f60fa_row14_col3 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_f60fa_row14_col4 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_f60fa_row14_col6, #T_f60fa_row21_col6 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_f60fa_row15_col4, #T_f60fa_row22_col1, #T_f60fa_row22_col3 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_f60fa_row16_col1 {
#   background-color: #d21f20;
#   color: #f1f1f1;
# }
# #T_f60fa_row16_col2 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_f60fa_row16_col3 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# #T_f60fa_row16_col4 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_f60fa_row16_col5, #T_f60fa_row20_col5, #T_f60fa_row25_col6 {
#   background-color: #f96044;
#   color: #f1f1f1;
# }
# #T_f60fa_row17_col1, #T_f60fa_row17_col3 {
#   background-color: #fc8e6e;
#   color: #000000;
# }
# #T_f60fa_row17_col4 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_f60fa_row20_col1, #T_f60fa_row20_col3, #T_f60fa_row28_col4 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_f60fa_row21_col4 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_f60fa_row22_col4 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_f60fa_row25_col1, #T_f60fa_row25_col3 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_f60fa_row25_col4 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_f60fa_row26_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_f60fa_row26_col3, #T_f60fa_row34_col1, #T_f60fa_row34_col3 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_f60fa_row26_col4 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_f60fa_row27_col6, #T_f60fa_row30_col6, #T_f60fa_row33_col5 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_f60fa_row28_col1, #T_f60fa_row28_col3 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_f60fa_row30_col4 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_f60fa_row31_col1, #T_f60fa_row31_col3 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_f60fa_row31_col2 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_f60fa_row31_col4 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_f60fa_row34_col4 {
#   background-color: #feeae1;
#   color: #000000;
# }
# </style>
# <table id="T_f60fa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Districts</th>
#       <th class="col_heading level0 col1" >Positive Cases</th>
#       <th class="col_heading level0 col2" >Active Cases</th>
#       <th class="col_heading level0 col3" >Recovered</th>
#       <th class="col_heading level0 col4" >Deceased</th>
#       <th class="col_heading level0 col5" >Recovery Rate(%)</th>
#       <th class="col_heading level0 col6" >Fatality Rate(%)</th>
#     <

# %% [markdown]
# Inference: -
#
# * Most number of Positive cases found in Pune district and on second position mumbai district.
# * Most number of Active Cases found in Pune distirct.
# * Most number of Recovered Cases found in Pune distirct.
# * Most number of Deceased Cases found in Pune distirct.
# * Buldhana district having highest recovery rate.
# * Ratnagiri distirct having highest fatality rate.

# %%
Total_Positive_Cases=dataframe.groupby("Districts")["Positive Cases"].sum().sort_values(ascending=False).to_frame()
Total_Positive_Cases.style.background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_62965_row0_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_62965_row1_col0 {
#   background-color: #de4e05;
#   color: #f1f1f1;
# }
# #T_62965_row2_col0 {
#   background-color: #fb8735;
#   color: #f1f1f1;
# }
# #T_62965_row3_col0 {
#   background-color: #fdab66;
#   color: #000000;
# }
# #T_62965_row4_col0 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_62965_row5_col0 {
#   background-color: #fdd1a3;
#   color: #000000;
# }
# #T_62965_row6_col0 {
#   background-color: #feddbc;
#   color: #000000;
# }
# #T_62965_row7_col0 {
#   background-color: #fee1c4;
#   color: #000000;
# }
# #T_62965_row8_col0, #T_62965_row9_col0 {
#   background-color: #fee3c8;
#   color: #000000;
# }
# #T_62965_row10_col0 {
#   background-color: #fee4ca;
#   color: #000000;
# }
# #T_62965_row11_col0 {
#   background-color: #fee8d2;
#   color: #000000;
# }
# #T_62965_row12_col0 {
#   background-color: #fee9d4;
#   color: #000000;
# }
# #T_62965_row13_col0 {
#   background-color: #feebd7;
#   color: #000000;
# }
# #T_62965_row14_col0 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# #T_62965_row15_col0, #T_62965_row16_col0, #T_62965_row17_col0 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_62965_row18_col0 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_62965_row19_col0 {
#   background-color: #ffefe0;
#   color: #000000;
# }
# #T_62965_row20_col0 {
#   background-color: #fff0e1;
#   color: #000000;
# }
# #T_62965_row21_col0 {
#   background-color: #fff0e2;
#   color: #000000;
# }
# #T_62965_row22_col0 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_62965_row23_col0 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_62965_row24_col0, #T_62965_row25_col0, #T_62965_row26_col0 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_62965_row27_col0, #T_62965_row28_col0 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_62965_row29_col0 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_62965_row30_col0, #T_62965_row31_col0, #T_62965_row32_col0 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_62965_row33_col0 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_62965_row34_col0 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_62965_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Positive Cases</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Districts</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62965_level0_row0" class="row_heading level0 row0" >Pune</th>
#       <td id="T_62965_row0_col0" class="data row0 col0" >1452208</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row1" class="row_heading level0 row1" >Mumbai</th>
#       <td id="T_62965_row1_col0" class="data row1 col0" >1056584</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row2" class="row_heading level0 row2" >Thane</th>
#       <td id="T_62965_row2_col0" class="data row2 col0" >766512</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row3" class="row_heading level0 row3" >Nagpur</th>
#       <td id="T_62965_row3_col0" class="data row3 col0" >576327</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row4" class="row_heading level0 row4" >Nashik</th>
#       <td id="T_62965_row4_col0" class="data row4 col0" >472767</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row5" class="row_heading level0 row5" >Ahmednagar</th>
#       <td id="T_62965_row5_col0" class="data row5 col0" >377366</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row6" class="row_heading level0 row6" >Satara</th>
#       <td id="T_62965_row6_col0" class="data row6 col0" >278152</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row7" class="row_heading level0 row7" >Raigad</th>
#       <td id="T_62965_row7_col0" class="data row7 col0" >244265</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row8" class="row_heading level0 row8" >Sangli</th>
#       <td id="T_62965_row8_col0" class="data row8 col0" >227023</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row9" class="row_heading level0 row9" >Solapur</th>
#       <td id="T_62965_row9_col0" class="data row9 col0" >227014</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row10" class="row_heading level0 row10" >Kolhapur</th>
#       <td id="T_62965_row10_col0" class="data row10 col0" >220452</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row11" class="row_heading level0 row11" >Aurangabad</th>
#       <td id="T_62965_row11_col0" class="data row11 col0" >176397</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row12" class="row_heading level0 row12" >Palghar</th>
#       <td id="T_62965_row12_col0" class="data row12 col0" >163447</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row13" class="row_heading level0 row13" >Jalgaon</th>
#       <td id="T_62965_row13_col0" class="data row13 col0" >149487</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row14" class="row_heading level0 row14" >Beed</th>
#       <td id="T_62965_row14_col0" class="data row14 col0" >109104</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row15" class="row_heading level0 row15" >Amravati</th>
#       <td id="T_62965_row15_col0" class="data row15 col0" >105928</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row16" class="row_heading level0 row16" >Latur</th>
#       <td id="T_62965_row16_col0" class="data row16 col0" >104910</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row17" class="row_heading level0 row17" >Nanded</th>
#       <td id="T_62965_row17_col0" class="data row17 col0" >102655</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row18" class="row_heading level0 row18" >Chandrapur</th>
#       <td id="T_62965_row18_col0" class="data row18 col0" >98812</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row19" class="row_heading level0 row19" >Buldhana</th>
#       <td id="T_62965_row19_col0" class="data row19 col0" >91916</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row20" class="row_heading level0 row20" >Ratnagiri</th>
#       <td id="T_62965_row20_col0" class="data row20 col0" >84404</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row21" class="row_heading level0 row21" >Yavatmal</th>
#       <td id="T_62965_row21_col0" class="data row21 col0" >81978</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row22" class="row_heading level0 row22" >Osmanabad</th>
#       <td id="T_62965_row22_col0" class="data row22 col0" >75135</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row23" class="row_heading level0 row23" >Bhandara</th>
#       <td id="T_62965_row23_col0" class="data row23 col0" >67937</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row24" class="row_heading level0 row24" >Jalna</th>
#       <td id="T_62965_row24_col0" class="data row24 col0" >66309</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row25" class="row_heading level0 row25" >Akola</th>
#       <td id="T_62965_row25_col0" class="data row25 col0" >66163</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row26" class="row_heading level0 row26" >Wardha</th>
#       <td id="T_62965_row26_col0" class="data row26 col0" >65663</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row27" class="row_heading level0 row27" >Parbhani</th>
#       <td id="T_62965_row27_col0" class="data row27 col0" >58532</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row28" class="row_heading level0 row28" >Sindhudurg</th>
#       <td id="T_62965_row28_col0" class="data row28 col0" >57144</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row29" class="row_heading level0 row29" >Dhule</th>
#       <td id="T_62965_row29_col0" class="data row29 col0" >50705</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row30" class="row_heading level0 row30" >Nandurbar</th>
#       <td id="T_62965_row30_col0" class="data row30 col0" >46611</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row31" class="row_heading level0 row31" >Washim</th>
#       <td id="T_62965_row31_col0" class="data row31 col0" >45614</td>
#     </tr>
#     <tr>
#       <th id="T_62965_level0_row32" class="row_heading level0 row32" >Gondia</th>
#       <td id="T_62965_row3

# %% [markdown]
# **Total Active Cases in Maharashtra in Descending Order**

# %%
Total_Active_Cases=dataframe.groupby("Districts")["Active Cases"].sum().sort_values(ascending=False).to_frame()
Total_Active_Cases.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_67b49_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_67b49_row1_col0 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_67b49_row2_col0 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_67b49_row3_col0 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_67b49_row4_col0 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_67b49_row5_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_67b49_row6_col0 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_67b49_row7_col0 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_67b49_row8_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_67b49_row9_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_67b49_row10_col0 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_67b49_row11_col0 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_67b49_row12_col0, #T_67b49_row13_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_67b49_row14_col0 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_67b49_row15_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_67b49_row16_col0, #T_67b49_row17_col0, #T_67b49_row18_col0, #T_67b49_row19_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_67b49_row20_col0, #T_67b49_row21_col0, #T_67b49_row22_col0, #T_67b49_row23_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_67b49_row24_col0, #T_67b49_row25_col0, #T_67b49_row26_col0, #T_67b49_row27_col0, #T_67b49_row28_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_67b49_row29_col0, #T_67b49_row30_col0, #T_67b49_row31_col0, #T_67b49_row32_col0, #T_67b49_row33_col0, #T_67b49_row34_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_67b49_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Active Cases</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Districts</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67b49_level0_row0" class="row_heading level0 row0" >Pune</th>
#       <td id="T_67b49_row0_col0" class="data row0 col0" >622</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row1" class="row_heading level0 row1" >Mumbai</th>
#       <td id="T_67b49_row1_col0" class="data row1 col0" >317</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row2" class="row_heading level0 row2" >Thane</th>
#       <td id="T_67b49_row2_col0" class="data row2 col0" >168</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row3" class="row_heading level0 row3" >Ahmednagar</th>
#       <td id="T_67b49_row3_col0" class="data row3 col0" >162</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row4" class="row_heading level0 row4" >Nashik</th>
#       <td id="T_67b49_row4_col0" class="data row4 col0" >74</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row5" class="row_heading level0 row5" >Aurangabad</th>
#       <td id="T_67b49_row5_col0" class="data row5 col0" >44</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row6" class="row_heading level0 row6" >Nagpur</th>
#       <td id="T_67b49_row6_col0" class="data row6 col0" >35</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row7" class="row_heading level0 row7" >Raigad</th>
#       <td id="T_67b49_row7_col0" class="data row7 col0" >32</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row8" class="row_heading level0 row8" >Satara</th>
#       <td id="T_67b49_row8_col0" class="data row8 col0" >30</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row9" class="row_heading level0 row9" >Kolhapur</th>
#       <td id="T_67b49_row9_col0" class="data row9 col0" >22</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row10" class="row_heading level0 row10" >Buldhana</th>
#       <td id="T_67b49_row10_col0" class="data row10 col0" >21</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row11" class="row_heading level0 row11" >Solapur</th>
#       <td id="T_67b49_row11_col0" class="data row11 col0" >19</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row12" class="row_heading level0 row12" >Gondia</th>
#       <td id="T_67b49_row12_col0" class="data row12 col0" >15</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row13" class="row_heading level0 row13" >Beed</th>
#       <td id="T_67b49_row13_col0" class="data row13 col0" >15</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row14" class="row_heading level0 row14" >Sindhudurg</th>
#       <td id="T_67b49_row14_col0" class="data row14 col0" >13</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row15" class="row_heading level0 row15" >Palghar</th>
#       <td id="T_67b49_row15_col0" class="data row15 col0" >10</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row16" class="row_heading level0 row16" >Parbhani</th>
#       <td id="T_67b49_row16_col0" class="data row16 col0" >9</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row17" class="row_heading level0 row17" >Latur</th>
#       <td id="T_67b49_row17_col0" class="data row17 col0" >9</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row18" class="row_heading level0 row18" >Nanded</th>
#       <td id="T_67b49_row18_col0" class="data row18 col0" >9</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row19" class="row_heading level0 row19" >Akola</th>
#       <td id="T_67b49_row19_col0" class="data row19 col0" >8</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row20" class="row_heading level0 row20" >Gadchiroli</th>
#       <td id="T_67b49_row20_col0" class="data row20 col0" >7</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row21" class="row_heading level0 row21" >Sangli</th>
#       <td id="T_67b49_row21_col0" class="data row21 col0" >7</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row22" class="row_heading level0 row22" >Osmanabad</th>
#       <td id="T_67b49_row22_col0" class="data row22 col0" >6</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row23" class="row_heading level0 row23" >Ratnagiri</th>
#       <td id="T_67b49_row23_col0" class="data row23 col0" >6</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row24" class="row_heading level0 row24" >Amravati</th>
#       <td id="T_67b49_row24_col0" class="data row24 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row25" class="row_heading level0 row25" >Jalgaon</th>
#       <td id="T_67b49_row25_col0" class="data row25 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row26" class="row_heading level0 row26" >Washim</th>
#       <td id="T_67b49_row26_col0" class="data row26 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row27" class="row_heading level0 row27" >Chandrapur</th>
#       <td id="T_67b49_row27_col0" class="data row27 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row28" class="row_heading level0 row28" >Nandurbar</th>
#       <td id="T_67b49_row28_col0" class="data row28 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row29" class="row_heading level0 row29" >Bhandara</th>
#       <td id="T_67b49_row29_col0" class="data row29 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row30" class="row_heading level0 row30" >Jalna</th>
#       <td id="T_67b49_row30_col0" class="data row30 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row31" class="row_heading level0 row31" >Wardha</th>
#       <td id="T_67b49_row31_col0" class="data row31 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row32" class="row_heading level0 row32" >Dhule</th>
#       <td id="T_67b49_row32_col0" class="data row32 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row33" class="row_heading level0 row33" >Hingoli</th>
#       <td id="T_67b49_row33_col0" class="data row33 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_67b49_level0_row34" class="row_heading level0 row34" >Yavatmal</th>
#       <td id="T_67b49_row34_col0" class="data row34 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Total Recovered Cases in Maharashtra in Descending Order**

# %%
Total_Recovered_Cases=dataframe.groupby("Districts")["Recovered"].sum().sort_values(ascending=False).to_frame()
Total_Recovered_Cases.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_21bed_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_21bed_row1_col0 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_21bed_row2_col0 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_21bed_row3_col0 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_21bed_row4_col0 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_21bed_row5_col0 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_21bed_row6_col0 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_21bed_row7_col0 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_21bed_row8_col0, #T_21bed_row9_col0 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_21bed_row10_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_21bed_row11_col0 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_21bed_row12_col0 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_21bed_row13_col0 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_21bed_row14_col0, #T_21bed_row15_col0 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_21bed_row16_col0, #T_21bed_row17_col0 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_21bed_row18_col0 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_21bed_row19_col0 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_21bed_row20_col0, #T_21bed_row21_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_21bed_row22_col0 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_21bed_row23_col0 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_21bed_row24_col0, #T_21bed_row25_col0, #T_21bed_row26_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_21bed_row27_col0, #T_21bed_row28_col0 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_21bed_row29_col0 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_21bed_row30_col0, #T_21bed_row31_col0, #T_21bed_row32_col0 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_21bed_row33_col0 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_21bed_row34_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_21bed_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Recovered</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Districts</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21bed_level0_row0" class="row_heading level0 row0" >Pune</th>
#       <td id="T_21bed_row0_col0" class="data row0 col0" >1431073</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row1" class="row_heading level0 row1" >Mumbai</th>
#       <td id="T_21bed_row1_col0" class="data row1 col0" >1036711</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row2" class="row_heading level0 row2" >Thane</th>
#       <td id="T_21bed_row2_col0" class="data row2 col0" >754440</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row3" class="row_heading level0 row3" >Nagpur</th>
#       <td id="T_21bed_row3_col0" class="data row3 col0" >567078</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row4" class="row_heading level0 row4" >Nashik</th>
#       <td id="T_21bed_row4_col0" class="data row4 col0" >463788</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row5" class="row_heading level0 row5" >Ahmednagar</th>
#       <td id="T_21bed_row5_col0" class="data row5 col0" >369963</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row6" class="row_heading level0 row6" >Satara</th>
#       <td id="T_21bed_row6_col0" class="data row6 col0" >271411</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row7" class="row_heading level0 row7" >Raigad</th>
#       <td id="T_21bed_row7_col0" class="data row7 col0" >239289</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row8" class="row_heading level0 row8" >Sangli</th>
#       <td id="T_21bed_row8_col0" class="data row8 col0" >221352</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row9" class="row_heading level0 row9" >Solapur</th>
#       <td id="T_21bed_row9_col0" class="data row9 col0" >221119</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row10" class="row_heading level0 row10" >Kolhapur</th>
#       <td id="T_21bed_row10_col0" class="data row10 col0" >214526</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row11" class="row_heading level0 row11" >Aurangabad</th>
#       <td id="T_21bed_row11_col0" class="data row11 col0" >172069</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row12" class="row_heading level0 row12" >Palghar</th>
#       <td id="T_21bed_row12_col0" class="data row12 col0" >160030</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row13" class="row_heading level0 row13" >Jalgaon</th>
#       <td id="T_21bed_row13_col0" class="data row13 col0" >146722</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row14" class="row_heading level0 row14" >Beed</th>
#       <td id="T_21bed_row14_col0" class="data row14 col0" >106207</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row15" class="row_heading level0 row15" >Amravati</th>
#       <td id="T_21bed_row15_col0" class="data row15 col0" >104300</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row16" class="row_heading level0 row16" >Latur</th>
#       <td id="T_21bed_row16_col0" class="data row16 col0" >102412</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row17" class="row_heading level0 row17" >Nanded</th>
#       <td id="T_21bed_row17_col0" class="data row17 col0" >99942</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row18" class="row_heading level0 row18" >Chandrapur</th>
#       <td id="T_21bed_row18_col0" class="data row18 col0" >97217</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row19" class="row_heading level0 row19" >Buldhana</th>
#       <td id="T_21bed_row19_col0" class="data row19 col0" >91065</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row20" class="row_heading level0 row20" >Ratnagiri</th>
#       <td id="T_21bed_row20_col0" class="data row20 col0" >81852</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row21" class="row_heading level0 row21" >Yavatmal</th>
#       <td id="T_21bed_row21_col0" class="data row21 col0" >80158</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row22" class="row_heading level0 row22" >Osmanabad</th>
#       <td id="T_21bed_row22_col0" class="data row22 col0" >72990</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row23" class="row_heading level0 row23" >Bhandara</th>
#       <td id="T_21bed_row23_col0" class="data row23 col0" >66794</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row24" class="row_heading level0 row24" >Jalna</th>
#       <td id="T_21bed_row24_col0" class="data row24 col0" >65084</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row25" class="row_heading level0 row25" >Akola</th>
#       <td id="T_21bed_row25_col0" class="data row25 col0" >64686</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row26" class="row_heading level0 row26" >Wardha</th>
#       <td id="T_21bed_row26_col0" class="data row26 col0" >64254</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row27" class="row_heading level0 row27" >Parbhani</th>
#       <td id="T_21bed_row27_col0" class="data row27 col0" >57247</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row28" class="row_heading level0 row28" >Sindhudurg</th>
#       <td id="T_21bed_row28_col0" class="data row28 col0" >55603</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row29" class="row_heading level0 row29" >Dhule</th>
#       <td id="T_21bed_row29_col0" class="data row29 col0" >50035</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row30" class="row_heading level0 row30" >Nandurbar</th>
#       <td id="T_21bed_row30_col0" class="data row30 col0" >45646</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row31" class="row_heading level0 row31" >Washim</th>
#       <td id="T_21bed_row31_col0" class="data row31 col0" >44970</td>
#     </tr>
#     <tr>
#       <th id="T_21bed_level0_row32" class="row_heading level0 row32" >Gondia</th>
#       <td id="T_21bed_row32_col0" class="data row32 col0" >44812</td>
#     </tr>

# %% [markdown]
# **Total Deceased Cases in Maharashtra in Descending Order**

# %%
Total_Deceased_Cases=dataframe.groupby("Districts")["Deceased"].sum().sort_values(ascending=False).to_frame()
Total_Deceased_Cases.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_b9e6b_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b9e6b_row1_col0 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_b9e6b_row2_col0 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_b9e6b_row3_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_b9e6b_row4_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_b9e6b_row5_col0 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_b9e6b_row6_col0 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_b9e6b_row7_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_b9e6b_row8_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_b9e6b_row9_col0 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_b9e6b_row10_col0 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_b9e6b_row11_col0 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_b9e6b_row12_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_b9e6b_row13_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_b9e6b_row14_col0, #T_b9e6b_row15_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_b9e6b_row16_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_b9e6b_row17_col0 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_b9e6b_row18_col0 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_b9e6b_row19_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_b9e6b_row20_col0, #T_b9e6b_row21_col0 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_b9e6b_row22_col0 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_b9e6b_row23_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_b9e6b_row24_col0, #T_b9e6b_row25_col0, #T_b9e6b_row26_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_b9e6b_row27_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_b9e6b_row28_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_b9e6b_row29_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_b9e6b_row30_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_b9e6b_row31_col0, #T_b9e6b_row32_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_b9e6b_row33_col0, #T_b9e6b_row34_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_b9e6b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Deceased</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Districts</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9e6b_level0_row0" class="row_heading level0 row0" >Pune</th>
#       <td id="T_b9e6b_row0_col0" class="data row0 col0" >20163</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row1" class="row_heading level0 row1" >Mumbai</th>
#       <td id="T_b9e6b_row1_col0" class="data row1 col0" >16693</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row2" class="row_heading level0 row2" >Thane</th>
#       <td id="T_b9e6b_row2_col0" class="data row2 col0" >11869</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row3" class="row_heading level0 row3" >Nagpur</th>
#       <td id="T_b9e6b_row3_col0" class="data row3 col0" >9143</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row4" class="row_heading level0 row4" >Nashik</th>
#       <td id="T_b9e6b_row4_col0" class="data row4 col0" >8904</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row5" class="row_heading level0 row5" >Ahmednagar</th>
#       <td id="T_b9e6b_row5_col0" class="data row5 col0" >7230</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row6" class="row_heading level0 row6" >Satara</th>
#       <td id="T_b9e6b_row6_col0" class="data row6 col0" >6677</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row7" class="row_heading level0 row7" >Kolhapur</th>
#       <td id="T_b9e6b_row7_col0" class="data row7 col0" >5899</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row8" class="row_heading level0 row8" >Solapur</th>
#       <td id="T_b9e6b_row8_col0" class="data row8 col0" >5759</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row9" class="row_heading level0 row9" >Sangli</th>
#       <td id="T_b9e6b_row9_col0" class="data row9 col0" >5655</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row10" class="row_heading level0 row10" >Raigad</th>
#       <td id="T_b9e6b_row10_col0" class="data row10 col0" >4937</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row11" class="row_heading level0 row11" >Aurangabad</th>
#       <td id="T_b9e6b_row11_col0" class="data row11 col0" >4270</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row12" class="row_heading level0 row12" >Palghar</th>
#       <td id="T_b9e6b_row12_col0" class="data row12 col0" >3392</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row13" class="row_heading level0 row13" >Beed</th>
#       <td id="T_b9e6b_row13_col0" class="data row13 col0" >2875</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row14" class="row_heading level0 row14" >Jalgaon</th>
#       <td id="T_b9e6b_row14_col0" class="data row14 col0" >2728</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row15" class="row_heading level0 row15" >Nanded</th>
#       <td id="T_b9e6b_row15_col0" class="data row15 col0" >2697</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row16" class="row_heading level0 row16" >Ratnagiri</th>
#       <td id="T_b9e6b_row16_col0" class="data row16 col0" >2541</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row17" class="row_heading level0 row17" >Latur</th>
#       <td id="T_b9e6b_row17_col0" class="data row17 col0" >2483</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row18" class="row_heading level0 row18" >Osmanabad</th>
#       <td id="T_b9e6b_row18_col0" class="data row18 col0" >2023</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row19" class="row_heading level0 row19" >Yavatmal</th>
#       <td id="T_b9e6b_row19_col0" class="data row19 col0" >1816</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row20" class="row_heading level0 row20" >Amravati</th>
#       <td id="T_b9e6b_row20_col0" class="data row20 col0" >1622</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row21" class="row_heading level0 row21" >Chandrapur</th>
#       <td id="T_b9e6b_row21_col0" class="data row21 col0" >1588</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row22" class="row_heading level0 row22" >Sindhudurg</th>
#       <td id="T_b9e6b_row22_col0" class="data row22 col0" >1513</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row23" class="row_heading level0 row23" >Akola</th>
#       <td id="T_b9e6b_row23_col0" class="data row23 col0" >1465</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row24" class="row_heading level0 row24" >Parbhani</th>
#       <td id="T_b9e6b_row24_col0" class="data row24 col0" >1256</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row25" class="row_heading level0 row25" >Wardha</th>
#       <td id="T_b9e6b_row25_col0" class="data row25 col0" >1237</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row26" class="row_heading level0 row26" >Jalna</th>
#       <td id="T_b9e6b_row26_col0" class="data row26 col0" >1223</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row27" class="row_heading level0 row27" >Bhandara</th>
#       <td id="T_b9e6b_row27_col0" class="data row27 col0" >1132</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row28" class="row_heading level0 row28" >Nandurbar</th>
#       <td id="T_b9e6b_row28_col0" class="data row28 col0" >959</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row29" class="row_heading level0 row29" >Buldhana</th>
#       <td id="T_b9e6b_row29_col0" class="data row29 col0" >824</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row30" class="row_heading level0 row30" >Gadchiroli</th>
#       <td id="T_b9e6b_row30_col0" class="data row30 col0" >691</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row31" class="row_heading level0 row31" >Dhule</th>
#       <td id="T_b9e6b_row31_col0" class="data row31 col0" >659</td>
#     </tr>
#     <tr>
#       <th id="T_b9e6b_level0_row32" class="row_heading level0 r

# %%
Total_Recovery_Rate=dataframe.groupby("Districts")["Recovery Rate(%)"].sum().sort_values(ascending=False).to_frame()
Total_Recovery_Rate.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_d0ae8_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_d0ae8_row1_col0, #T_d0ae8_row2_col0 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_d0ae8_row3_col0 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# #T_d0ae8_row4_col0, #T_d0ae8_row5_col0 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_d0ae8_row6_col0, #T_d0ae8_row7_col0, #T_d0ae8_row8_col0 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_d0ae8_row9_col0 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_d0ae8_row10_col0, #T_d0ae8_row11_col0 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_d0ae8_row12_col0, #T_d0ae8_row13_col0 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_d0ae8_row14_col0, #T_d0ae8_row15_col0, #T_d0ae8_row16_col0 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_d0ae8_row17_col0, #T_d0ae8_row18_col0, #T_d0ae8_row19_col0 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_d0ae8_row20_col0, #T_d0ae8_row21_col0, #T_d0ae8_row22_col0 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_d0ae8_row23_col0 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_d0ae8_row24_col0, #T_d0ae8_row25_col0 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_d0ae8_row26_col0, #T_d0ae8_row27_col0 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_d0ae8_row28_col0, #T_d0ae8_row29_col0 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_d0ae8_row30_col0, #T_d0ae8_row31_col0, #T_d0ae8_row32_col0 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_d0ae8_row33_col0 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_d0ae8_row34_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_d0ae8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Recovery Rate(%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Districts</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0ae8_level0_row0" class="row_heading level0 row0" >Buldhana</th>
#       <td id="T_d0ae8_row0_col0" class="data row0 col0" >99.100000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row1" class="row_heading level0 row1" >Dhule</th>
#       <td id="T_d0ae8_row1_col0" class="data row1 col0" >98.700000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row2" class="row_heading level0 row2" >Gondia</th>
#       <td id="T_d0ae8_row2_col0" class="data row2 col0" >98.700000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row3" class="row_heading level0 row3" >Washim</th>
#       <td id="T_d0ae8_row3_col0" class="data row3 col0" >98.600000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row4" class="row_heading level0 row4" >Amravati</th>
#       <td id="T_d0ae8_row4_col0" class="data row4 col0" >98.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row5" class="row_heading level0 row5" >Pune</th>
#       <td id="T_d0ae8_row5_col0" class="data row5 col0" >98.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row6" class="row_heading level0 row6" >Nagpur</th>
#       <td id="T_d0ae8_row6_col0" class="data row6 col0" >98.400000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row7" class="row_heading level0 row7" >Thane</th>
#       <td id="T_d0ae8_row7_col0" class="data row7 col0" >98.400000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row8" class="row_heading level0 row8" >Chandrapur</th>
#       <td id="T_d0ae8_row8_col0" class="data row8 col0" >98.400000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row9" class="row_heading level0 row9" >Bhandara</th>
#       <td id="T_d0ae8_row9_col0" class="data row9 col0" >98.300000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row10" class="row_heading level0 row10" >Jalgaon</th>
#       <td id="T_d0ae8_row10_col0" class="data row10 col0" >98.200000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row11" class="row_heading level0 row11" >Jalna</th>
#       <td id="T_d0ae8_row11_col0" class="data row11 col0" >98.200000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row12" class="row_heading level0 row12" >Mumbai</th>
#       <td id="T_d0ae8_row12_col0" class="data row12 col0" >98.100000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row13" class="row_heading level0 row13" >Nashik</th>
#       <td id="T_d0ae8_row13_col0" class="data row13 col0" >98.100000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row14" class="row_heading level0 row14" >Raigad</th>
#       <td id="T_d0ae8_row14_col0" class="data row14 col0" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row15" class="row_heading level0 row15" >Ahmednagar</th>
#       <td id="T_d0ae8_row15_col0" class="data row15 col0" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row16" class="row_heading level0 row16" >Gadchiroli</th>
#       <td id="T_d0ae8_row16_col0" class="data row16 col0" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row17" class="row_heading level0 row17" >Palghar</th>
#       <td id="T_d0ae8_row17_col0" class="data row17 col0" >97.900000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row18" class="row_heading level0 row18" >Wardha</th>
#       <td id="T_d0ae8_row18_col0" class="data row18 col0" >97.900000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row19" class="row_heading level0 row19" >Nandurbar</th>
#       <td id="T_d0ae8_row19_col0" class="data row19 col0" >97.900000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row20" class="row_heading level0 row20" >Akola</th>
#       <td id="T_d0ae8_row20_col0" class="data row20 col0" >97.800000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row21" class="row_heading level0 row21" >Parbhani</th>
#       <td id="T_d0ae8_row21_col0" class="data row21 col0" >97.800000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row22" class="row_heading level0 row22" >Yavatmal</th>
#       <td id="T_d0ae8_row22_col0" class="data row22 col0" >97.800000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row23" class="row_heading level0 row23" >Hingoli</th>
#       <td id="T_d0ae8_row23_col0" class="data row23 col0" >97.700000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row24" class="row_heading level0 row24" >Satara</th>
#       <td id="T_d0ae8_row24_col0" class="data row24 col0" >97.600000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row25" class="row_heading level0 row25" >Latur</th>
#       <td id="T_d0ae8_row25_col0" class="data row25 col0" >97.600000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row26" class="row_heading level0 row26" >Sangli</th>
#       <td id="T_d0ae8_row26_col0" class="data row26 col0" >97.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row27" class="row_heading level0 row27" >Aurangabad</th>
#       <td id="T_d0ae8_row27_col0" class="data row27 col0" >97.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row28" class="row_heading level0 row28" >Solapur</th>
#       <td id="T_d0ae8_row28_col0" class="data row28 col0" >97.400000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row29" class="row_heading level0 row29" >Nanded</th>
#       <td id="T_d0ae8_row29_col0" class="data row29 col0" >97.400000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row30" class="row_heading level0 row30" >Kolhapur</th>
#       <td id="T_d0ae8_row30_col0" class="data row30 col0" >97.300000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row31" class="row_heading level0 row31" >Sindhudurg</th>
#       <td id="T_d0ae8_row31_col0" class="data row31 col0" >97.300000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row32" class="row_heading level0 row32" >Beed</th>
#       <td id="T_d0ae8_row32_col0" class="data row32 col0" >97.300000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row33" class="row_heading level0 row33" >Osmanabad</th>
#       <td id="T_d0ae8_row33_col0" class="data row33 col0" >97.100000</td>
#     </tr>
#     <tr>
#       <th id="T_d0ae8_level0_row34" class="row_heading level0 row34" >Ratnagiri</th>
#       <td i

# %% [markdown]
# # **Covid 19 Maharashtra Data Visuliazation**

# %% [markdown]
# * Total Positive cases in Maharashtra Districtwise

# %%
fig=px.bar(dataframe,x="Districts",y="Positive Cases",title="Total Positive cases in Maharashtra Districtwise",color='Districts')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1e8f95ae-af48-4211-bc7e-441ba78a85d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e8f95ae-af48-4211-bc7e-441ba78a85d7")) {                    Plotly.newPlot(                        "1e8f95ae-af48-4211-bc7e-441ba78a85d7",                        [{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Positive Cases=%{y}<extra></extra>","legendgroup":"Ahmednagar","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Ahmednagar","offsetgroup":"Ahmednagar","orientation":"v","showlegend":true,"textposition":"auto","x":["Ahmednagar"],"xaxis":"x","y":[377366],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Positive Cases=%{y}<extra></extra>","legendgroup":"Akola","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Akola","offsetgroup":"Akola","orientation":"v","showlegend":true,"textposition":"auto","x":["Akola"],"xaxis":"x","y":[66163],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Positive Cases=%{y}<extra></extra>","legendgroup":"Amravati","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Amravati","offsetgroup":"Amravati","orientation":"v","showlegend":true,"textposition":"auto","x":["Amravati"],"xaxis":"x","y":[105928],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Positive Cases=%{y}<extra></extra>","legendgroup":"Aurangabad","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Aurangabad","offsetgroup":"Aurangabad","orientation":"v","showlegend":true,"textposition":"auto","x":["Aurangabad"],"xaxis":"x","y":[176397],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Positive Cases=%{y}<extra></extra>","legendgroup":"Beed","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Beed","offsetgroup":"Beed","orientation":"v","showlegend":true,"textposition":"auto","x":["Beed"],"xaxis":"x","y":[109104],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Positive Cases=%{y}<extra></extra>","legendgroup":"Bhandara","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Bhandara","offsetgroup":"Bhandara","orientation":"v","showlegend":true,"textposition":"auto","x":["Bhandara"],"xaxis":"x","y":[67937],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Positive Cases=%{y}<extra></extra>","legendgroup":"Buldhana","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Buldhana","offsetgroup":"Buldhana","orientation":"v","showlegend":true,"textposition":"auto","x":["Buldhana"],"xaxis":"x","y":[91916],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Positive Cases=%{y}<extra></extra>","legendgroup":"Chandrapur","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Chandrapur","offsetgroup":"Chandrapur","orientation":"v","showlegend":true,"textposition":"auto","x":["Chandrapur"],"xaxis":"x","y":[98812],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Positive Cases=%{y}<extra></extra>","legendgroup":"Dhule","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Dhule","offsetgroup":"Dhule","orientation":"v","showlegend":true,"textposition":"auto","x":["Dhule"],"xaxis":"x","y":[50705],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Positive Cases=%{y}<extra></extra>","legendgroup":"Gadchiroli","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Gadchiroli","offsetgroup":"Gadchiroli","orientation":"v","showlegend":true,"textposition":"auto","x":["Gadchiroli"],"xaxis":"x","y":[36958],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Pos ...

# %% [markdown]
# **Total Active cases in Maharashtra Districtwise**

# %%
fig=px.bar(dataframe,x="Districts",y="Active Cases",title="Total Active cases in Maharashtra Districtwise",color='Districts')
fig.show()
# Out:
# <div>                            <div id="a362c1fb-8228-4bf8-9c6e-a572302efc47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a362c1fb-8228-4bf8-9c6e-a572302efc47")) {                    Plotly.newPlot(                        "a362c1fb-8228-4bf8-9c6e-a572302efc47",                        [{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Active Cases=%{y}<extra></extra>","legendgroup":"Ahmednagar","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Ahmednagar","offsetgroup":"Ahmednagar","orientation":"v","showlegend":true,"textposition":"auto","x":["Ahmednagar"],"xaxis":"x","y":[162],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Active Cases=%{y}<extra></extra>","legendgroup":"Akola","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Akola","offsetgroup":"Akola","orientation":"v","showlegend":true,"textposition":"auto","x":["Akola"],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Active Cases=%{y}<extra></extra>","legendgroup":"Amravati","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Amravati","offsetgroup":"Amravati","orientation":"v","showlegend":true,"textposition":"auto","x":["Amravati"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Active Cases=%{y}<extra></extra>","legendgroup":"Aurangabad","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Aurangabad","offsetgroup":"Aurangabad","orientation":"v","showlegend":true,"textposition":"auto","x":["Aurangabad"],"xaxis":"x","y":[44],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Active Cases=%{y}<extra></extra>","legendgroup":"Beed","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Beed","offsetgroup":"Beed","orientation":"v","showlegend":true,"textposition":"auto","x":["Beed"],"xaxis":"x","y":[15],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Active Cases=%{y}<extra></extra>","legendgroup":"Bhandara","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Bhandara","offsetgroup":"Bhandara","orientation":"v","showlegend":true,"textposition":"auto","x":["Bhandara"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Active Cases=%{y}<extra></extra>","legendgroup":"Buldhana","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Buldhana","offsetgroup":"Buldhana","orientation":"v","showlegend":true,"textposition":"auto","x":["Buldhana"],"xaxis":"x","y":[21],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Active Cases=%{y}<extra></extra>","legendgroup":"Chandrapur","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Chandrapur","offsetgroup":"Chandrapur","orientation":"v","showlegend":true,"textposition":"auto","x":["Chandrapur"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Active Cases=%{y}<extra></extra>","legendgroup":"Dhule","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Dhule","offsetgroup":"Dhule","orientation":"v","showlegend":true,"textposition":"auto","x":["Dhule"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Active Cases=%{y}<extra></extra>","legendgroup":"Gadchiroli","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Gadchiroli","offsetgroup":"Gadchiroli","orientation":"v","showlegend":true,"textposition":"auto","x":["Gadchiroli"],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Active Cases=%{y}<extra></extra>","legendgroup":"Gondia","mark ...

# %% [markdown]
# **Total Recovered cases in Maharashtra Districtwise**

# %%
fig=px.bar(dataframe,x="Districts",y="Recovered",title="Total Recovered cases in Maharashtra Districtwise",color='Districts')
fig.show()
# Out:
# <div>                            <div id="38113450-16af-487a-b438-916df26d2c2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38113450-16af-487a-b438-916df26d2c2c")) {                    Plotly.newPlot(                        "38113450-16af-487a-b438-916df26d2c2c",                        [{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"Ahmednagar","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Ahmednagar","offsetgroup":"Ahmednagar","orientation":"v","showlegend":true,"textposition":"auto","x":["Ahmednagar"],"xaxis":"x","y":[369963],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"Akola","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Akola","offsetgroup":"Akola","orientation":"v","showlegend":true,"textposition":"auto","x":["Akola"],"xaxis":"x","y":[64686],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"Amravati","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Amravati","offsetgroup":"Amravati","orientation":"v","showlegend":true,"textposition":"auto","x":["Amravati"],"xaxis":"x","y":[104300],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"Aurangabad","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Aurangabad","offsetgroup":"Aurangabad","orientation":"v","showlegend":true,"textposition":"auto","x":["Aurangabad"],"xaxis":"x","y":[172069],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"Beed","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Beed","offsetgroup":"Beed","orientation":"v","showlegend":true,"textposition":"auto","x":["Beed"],"xaxis":"x","y":[106207],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"Bhandara","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Bhandara","offsetgroup":"Bhandara","orientation":"v","showlegend":true,"textposition":"auto","x":["Bhandara"],"xaxis":"x","y":[66794],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"Buldhana","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Buldhana","offsetgroup":"Buldhana","orientation":"v","showlegend":true,"textposition":"auto","x":["Buldhana"],"xaxis":"x","y":[91065],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"Chandrapur","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Chandrapur","offsetgroup":"Chandrapur","orientation":"v","showlegend":true,"textposition":"auto","x":["Chandrapur"],"xaxis":"x","y":[97217],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"Dhule","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Dhule","offsetgroup":"Dhule","orientation":"v","showlegend":true,"textposition":"auto","x":["Dhule"],"xaxis":"x","y":[50035],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"Gadchiroli","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Gadchiroli","offsetgroup":"Gadchiroli","orientation":"v","showlegend":true,"textposition":"auto","x":["Gadchiroli"],"xaxis":"x","y":[36226],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"Gondia" ...

# %% [markdown]
# **Total Deceased cases in Maharashtra Districtwise**

# %%
fig=px.bar(dataframe,x="Districts",y="Deceased",title="Total Deceased cases in Maharashtra Districtwise",color='Districts')
fig.show()
# Out:
# <div>                            <div id="e42a3ce9-f5df-4dbf-94c5-a81ae8950fa6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e42a3ce9-f5df-4dbf-94c5-a81ae8950fa6")) {                    Plotly.newPlot(                        "e42a3ce9-f5df-4dbf-94c5-a81ae8950fa6",                        [{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Deceased=%{y}<extra></extra>","legendgroup":"Ahmednagar","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Ahmednagar","offsetgroup":"Ahmednagar","orientation":"v","showlegend":true,"textposition":"auto","x":["Ahmednagar"],"xaxis":"x","y":[7230],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Deceased=%{y}<extra></extra>","legendgroup":"Akola","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Akola","offsetgroup":"Akola","orientation":"v","showlegend":true,"textposition":"auto","x":["Akola"],"xaxis":"x","y":[1465],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Deceased=%{y}<extra></extra>","legendgroup":"Amravati","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Amravati","offsetgroup":"Amravati","orientation":"v","showlegend":true,"textposition":"auto","x":["Amravati"],"xaxis":"x","y":[1622],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Deceased=%{y}<extra></extra>","legendgroup":"Aurangabad","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Aurangabad","offsetgroup":"Aurangabad","orientation":"v","showlegend":true,"textposition":"auto","x":["Aurangabad"],"xaxis":"x","y":[4270],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Deceased=%{y}<extra></extra>","legendgroup":"Beed","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Beed","offsetgroup":"Beed","orientation":"v","showlegend":true,"textposition":"auto","x":["Beed"],"xaxis":"x","y":[2875],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Deceased=%{y}<extra></extra>","legendgroup":"Bhandara","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Bhandara","offsetgroup":"Bhandara","orientation":"v","showlegend":true,"textposition":"auto","x":["Bhandara"],"xaxis":"x","y":[1132],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Deceased=%{y}<extra></extra>","legendgroup":"Buldhana","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Buldhana","offsetgroup":"Buldhana","orientation":"v","showlegend":true,"textposition":"auto","x":["Buldhana"],"xaxis":"x","y":[824],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Deceased=%{y}<extra></extra>","legendgroup":"Chandrapur","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Chandrapur","offsetgroup":"Chandrapur","orientation":"v","showlegend":true,"textposition":"auto","x":["Chandrapur"],"xaxis":"x","y":[1588],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Deceased=%{y}<extra></extra>","legendgroup":"Dhule","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Dhule","offsetgroup":"Dhule","orientation":"v","showlegend":true,"textposition":"auto","x":["Dhule"],"xaxis":"x","y":[659],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Deceased=%{y}<extra></extra>","legendgroup":"Gadchiroli","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Gadchiroli","offsetgroup":"Gadchiroli","orientation":"v","showlegend":true,"textposition":"auto","x":["Gadchiroli"],"xaxis":"x","y":[691],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Districts=%{x}<br>Deceased=%{y}<extra></extra>","legendgroup":"Gondia","marker":{"color":"#636efa" ...

# %% [markdown]
# **Total Recovery Rate(%) VS Fatality Rate(%) in Maharashtra**

# %%
average_recovery_rate=round(dataframe["Recovery Rate(%)"].mean(),2)
average_fatality_rate=round(dataframe["Fatality Rate(%)"].mean(),2)
col=["Recovery Rate","Fatality rate"]
fig=px.pie(values=[average_recovery_rate,average_fatality_rate],names=col,title="Average Recovery and Fatality in Maharashtra",labels=col)
fig.show()
# Out:
# <div>                            <div id="dc426403-414e-49dc-8bbf-b4f5133c4976" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc426403-414e-49dc-8bbf-b4f5133c4976")) {                    Plotly.newPlot(                        "dc426403-414e-49dc-8bbf-b4f5133c4976",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Recovery Rate","Fatality rate"],"legendgroup":"","name":"","showlegend":true,"values":[97.94,2.01],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker": ...
#
# var gd = document.getElementById('dc426403-414e-49dc-8bbf-b4f5133c4976');
# var x = new MutationObserver

# %% [markdown]
# **Top 5 Affected district in Maharashtra**

# %%
top_5_district=dataframe.nlargest(5,['Positive Cases','Active Cases', 'Recovered', 'Deceased',
       'Recovery Rate(%)', 'Fatality Rate(%)'],'first')
print(top_5_district)
# Out:
#    Districts  Positive Cases  Active Cases  Recovered  Deceased  \
# 24      Pune         1452208           622    1431073     20163
# 16    Mumbai         1056584           317    1036711     16693
# 31     Thane          766512           168     754440     11869
# 17    Nagpur          576327            35     567078      9143
# 20    Nashik          472767            74     463788      8904
#
#     Recovery Rate(%)  Fatality Rate(%)
# 24              98.5               1.4
# 16              98.1               1.6
# 31              98.4               1.5
# 17              98.4               1.6
# 20              98.1               1.9

# %% [markdown]
# **Inference : -**
# Top 5 Affected district in Maharashtra
# * Pune
# * Mumbai
# * Thane
# * Nagpur
# * Nashik

# %% [markdown]
# **Bottom 5 Affected district in Maharashtra**

# %%
bottom_5_district=dataframe.nsmallest(5,['Positive Cases','Active Cases', 'Recovered', 'Deceased',
       'Recovery Rate(%)', 'Fatality Rate(%)'],'first')
print(bottom_5_district)
# Out:
#      Districts  Positive Cases  Active Cases  Recovered  Deceased  \
# 11     Hingoli           22166             0      21652       513
# 9   Gadchiroli           36958             7      36226       691
# 10      Gondia           45414            15      44812       580
# 33      Washim           45614             3      44970       638
# 19   Nandurbar           46611             3      45646       959
#
#     Recovery Rate(%)  Fatality Rate(%)
# 11              97.7               2.3
# 9               98.0               1.9
# 10              98.7               1.3
# 33              98.6               1.4
# 19              97.9               2.1

# %% [markdown]
# **Inference : -**
# Bottom 5 Affected district in Maharashtra
#
# * Hingoli
# * Gadchoroli
# * Gondia
# * Washim
# * Nandurbar

# %%
city_data=pd.read_csv("../input/maharashtra-longiutde-and-latiude-dataset/Longitude and Latitude of Maharashtra.csv")

# %%
city_data.columns
# Out:
# Index(['Location', 'Latitude', 'Longitude'], dtype='object')

# %%
city=city_data.rename(columns={'Location':'Districts'})

# %%
city.head()
# Out:
#     Districts  Latitude  Longitude
# 0  Ahmednagar     19.05      74.48
# 1       Akola     20.42      77.02
# 2    Amravati     20.56      77.48
# 3  Aurangabad     19.53      75.23
# 4    Bhandara     21.09      79.42

# %%
final_dataframe=pd.merge(dataframe,city,how='left',on='Districts')

# %%
final_dataframe.head()
# Out:
#     Districts  Positive Cases  Active Cases  Recovered  Deceased  \
# 0  Ahmednagar          377366           162     369963      7230
# 1       Akola           66163             8      64686      1465
# 2    Amravati          105928             4     104300      1622
# 3  Aurangabad          176397            44     172069      4270
# 4        Beed          109104            15     106207      2875
#
#    Recovery Rate(%)  Fatality Rate(%)  Latitude  Longitude
# 0              98.0               1.9     19.05      74.48
# 1              97.8               2.2     20.42      77.02
# 2              98.5               1.5     20.56      77.48
# 3              97.5               2.4     19.53      75.23
# 4              97.3               2.6     18.99      75.75

# %%
final_dataframe.at[32,'Latitude']='20.74'
final_dataframe.at[32,'Longitude']='78.60'

# %%
#here we make map on this of longitude and latitude coordinates and show total cases in india with highlighting.
map=folium.Map(location=[19.7515,75.7139],zoom_start=6.5,tiles='OpenStreetMap')

for lat,long,pos_cases,name,active,recovered,deceased in zip(final_dataframe["Latitude"],final_dataframe["Longitude"],final_dataframe["Positive Cases"],final_dataframe["Districts"],final_dataframe["Active Cases"],final_dataframe["Recovered"],final_dataframe["Deceased"]):
      folium.CircleMarker([lat,long],radius=pos_cases*0.0001,popup=(f'<strong>State:- {str(name).capitalize()}<br> <strong>Positive Cases:- {str(pos_cases)}<br> <strong>Active Cases:- {str(active)}<br> <strong>Recovered Cases:- {str(recovered)}<br> <strong>Deceased Cases:- {str(deceased)}<br>'),color='red',fill_color='red',fill_opacity=0.3).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_92b9a5093df3410198c3fa320543042d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_92b9a5093df3410198c3fa320543042d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_92b9a5093df3410198c3fa320543042d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_92b9a5093df3410198c3fa320543042d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B19.7515%2C%2075.7139%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# # **Analysis:-**
#
# 1) Most of the cases found in Pune district
#
# 2) Second most affected district is Mumbai.
#
# 3) Highest recovery rate at Buldhana district
#
# 4) Highest fatality rate at Ratnagiri district.
#
# 5) Rare cases found in Hingoli district
#
# 6) Lowest recovery rate at Buldhana district
#
# 7) Lowest fatality rate at Buldhana district
